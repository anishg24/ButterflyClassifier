# %%
import pandas as pd
import numpy as np
import os
import random
 
from sklearn.model_selection import train_test_split
from matplotlib.image import imread
from matplotlib import pyplot
from IPython.display import Image

DATA_DIR = "../data/leedsbutterfly"
DESC_DIR = DATA_DIR + "/descriptions/"
IMG_DIR = DATA_DIR + "/images/"
OUTFILE = "../data/dataframe.csv"

print("Setup all imports")
# Out:
# Setup all imports

# %%
temp = {
    "Name": [],
    "Scientific Name": [],
    "Description": [],
    "Image Files": [],
    "Image Arrays": [],
}
for f in os.listdir(DESC_DIR):
    file_dir = DESC_DIR + f"/{f}"
    with open(file_dir, 'r') as d:
        lines = d.readlines()
        temp["Scientific Name"].append(lines[0].strip())
        temp["Name"].append(lines[1].strip())
        temp["Description"].append(lines[2].strip())
    temp["Image Files"].append([i for i in os.listdir(IMG_DIR) if i.startswith(f[:3])])
    temp["Image Arrays"].append(np.array([imread(IMG_DIR + temp["Image Files"][-1][-i]) for i in range(len(temp["Image Files"]))]))
# temp

# %%
df = pd.DataFrame(temp, index=[i+1 for i in range(10)])

# %%
# This cell is solely to test how our DataFrame is structured and how to use it
species = df.iloc[random.randint(0,9)]
image = IMG_DIR + random.choice(species["Image Files"])

print(species["Name"])
print(species["Scientific Name"])
print(species["Description"])
Image(filename=image)
# Out:
# Mourning Cloak
# Nymphalis antiopa
# 2 7/8-3 3/8" (73-86 mm). Large. Wing margins ragged. Dark with pale margins. Above, rich brownish-maroon, iridescent at close range, with ragged, cream-yellow band, bordered inwardly by brilliant blue spots all along both wings. Below, striated, ash-black with row of blue-green to blue-gray chevrons just inside dirty yellow border.

# %%
# Save the new DataFrame
df.to_csv(OUTFILE)
print(f"Saved the file to {OUTFILE}")
# Out:
# Saved the file to ../data/dataframe.csv

# %%
pyplot.imshow(species["Image Arrays"][0])
pyplot.show()
Image(filename=IMG_DIR + species["Image Files"][0])

# %%
shape = species["Image Arrays"][0].shape
if shape[2] == 3:
    print("This is an RGB file")
# Out:
# This is an RGB file

# %%
# Work on getting data ready for model, i.e. reshape and save into another file.
index = 5
X = np.array(df["Image Arrays"])
y = np.array(df["Name"])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

for i in X:
    print(i.shape)
    for j in i:
        print(j.shape)
# Out:
# (1, 333, 500, 3)
# (333, 500, 3)
# (2,)
# (852, 1280, 3)
# (1067, 1600, 3)
# (3,)
# (600, 840, 3)
# (1998, 2664, 3)
# (399, 513, 3)
# (4,)
# (225, 300, 3)
# (332, 500, 3)
# (333, 500, 3)
# (353, 440, 3)
# (5,)
# (179, 269, 3)
# (154, 216, 3)
# (413, 640, 3)
# (1948, 2958, 3)
# (380, 540, 3)
# (6,)
# (450, 600, 3)
# (634, 800, 3)
# (439, 500, 3)
# (380, 531, 3)
# (609, 750, 3)
# (1200, 1600, 3)
# (7,)
# (217, 251, 3)
# (359, 500, 3)
# (192, 320, 3)
# (400, 500, 3)
# (456, 600, 3)
# (582, 800, 3)
# (473, 750, 3)
# (8,)
# (512, 768, 3)
# (553, 800, 3)
# (768, 1024, 3)
# (223, 301, 3)
# (282, 448, 3)
# (188, 250, 3)
# (550, 895, 3)
# (623, 800, 3)
# (9,)
# (480, 600, 3)
# (745, 1024, 3)
# (377, 560, 3)
# (652, 800, 3)
# (424, 500, 3)
# (473, 480, 3)
# (486, 650, 3)
# (250, 323, 3)
# (300, 450, 3)
# (10,)
# (286, 320, 3)
# (385, 567, 3)
# (427, 640, 3)
# (480, 640, 3)
# (320, 320, 3)
# (184, 207, 3)
# (570, 859, 3)
# (480, 640, 3)
# (175, 200, 3)
# (427, 640, 3)
